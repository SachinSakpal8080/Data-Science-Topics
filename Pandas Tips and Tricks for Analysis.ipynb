# %% [markdown]
# #### Conditional Selection of Rows:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(color_codes=True)

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('Loan Prediction III_train_ctrUa4K.csv')
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
data1 = data[(data['Education']=='Not Graduate') & (data['ApplicantIncome']<=5400)]
data1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 16   LP001034    Male      No          1  Not Graduate            No
# 18   LP001038    Male     Yes          0  Not Graduate            No
# 22   LP001047    Male     Yes          0  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 587  LP002917  Female      No          0  Not Graduate            No
# 595  LP002940    Male      No          0  Not Graduate            No
# 601  LP002950    Male     Yes          0  Not Graduate           NaN
# 605  LP002960    Male     Yes          0  Not Graduate            No
# 607  LP002964    Male     Yes          2  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data2 = data[(data['Education']=='Graduate') & (data['ApplicantIncome']>8000)]
data2
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 9    LP001020    Male     Yes          1  Graduate            No
# 25   LP001066    Male     Yes          0  Graduate           Yes
# 34   LP001100    Male      No         3+  Graduate            No
# 54   LP001186  Female     Yes          1  Graduate           Yes
# 58   LP001198    Male     Yes          1  Graduate            No
# ..        ...     ...     ...        ...       ...           ...
# 592  LP002933     NaN      No         3+  Graduate           Yes
# 594  LP002938    Male     Yes          0  Graduate           Yes
# 598  LP002945    Male     Yes          0  Graduate           Yes
# 604  LP002959  Female     Yes          1  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 9              12841            10968.0       349.0             360.0
# ...

# %%
data3 = data[(data['Education']=='Graduate') & (data['ApplicantIncome']>data['ApplicantIncome'].mean())]
data3.shape[0]
# Out:
# 159

# %% [markdown]
# #### Binning of Data

# %% [markdown]
# For instance, you have a continuous variable in your data – age. But you require an age group for your analysis such as – child, teenager, adult, senior citizen. Indeed, Binning is perfect to solve our problem here.
#
# To perform binning, we use the cut() function. This useful for going from a continuous variable to a categorical variable.

# %%
bins = [0, 5000, 20000, 55000, 100000]
labels = ['Low', 'Moderate', 'High', 'Very_High']
category = pd.cut(data['ApplicantIncome'], bins = bins, labels = labels)

# %%
data.insert(2, 'Category', category)

# %%
data.head()
# Out:
#     Loan_ID Gender  Category Married Dependents     Education Self_Employed  \
# 0  LP001002   Male  Moderate      No          0      Graduate            No
# 1  LP001003   Male       Low     Yes          1      Graduate            No
# 2  LP001005   Male       Low     Yes          0      Graduate           Yes
# 3  LP001006   Male       Low     Yes          0  Not Graduate            No
# 4  LP001008   Male  Moderate      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# ...

# %% [markdown]
# #### Grouping Data

# %% [markdown]
# This operation is frequently performed in the daily lives of data scientists and analysts. Pandas provide an essential function to perform grouping of data which is Groupby.

# %%
data.groupby('Gender')['ApplicantIncome'].mean()
# Out:
# Gender
# Female    4643.473214
# Male      5446.460123
# Name: ApplicantIncome, dtype: float64

# %%
data.groupby('Gender')['ApplicantIncome'].median()
# Out:
# Gender
# Female    3583
# Male      3865
# Name: ApplicantIncome, dtype: int64

# %%
data.groupby('Loan_Amount_Term')['ApplicantIncome'].mean()
# Out:
# Loan_Amount_Term
# 12.0     4625.000000
# 36.0     3419.500000
# 60.0     5032.500000
# 84.0     4128.500000
# 120.0    2792.666667
# 180.0    6927.886364
# 240.0    5907.750000
# 300.0    8184.923077
# 360.0    5298.083984
# 480.0    4398.933333
# Name: ApplicantIncome, dtype: float64

# %%
data.groupby('Property_Area')['ApplicantIncome'].mean()
# Out:
# Property_Area
# Rural        5554.083799
# Semiurban    5292.261803
# Urban        5398.247525
# Name: ApplicantIncome, dtype: float64

# %%
data.groupby('Credit_History')['ApplicantIncome'].mean()
# Out:
# Credit_History
# 0.0    5679.438202
# 1.0    5426.526316
# Name: ApplicantIncome, dtype: float64

# %% [markdown]
# #### Pandas Mapping

# %%
data.style
# Out:
# <style  type="text/css" >
# ...

# %%
def highlight(ApplicantIncome):
    color = 'green' if ApplicantIncome>5000 else 'red'
    return 'color: %s' % color

# %%
formatting = data.iloc[0:6,7:8].style.applymap(highlight)

# %%
formatting
# Out:
# <style  type="text/css" >
#     #T_f5f8e60a_087e_11eb_b041_9c7bef15ac82row0_col0 {
#             color:  green;
#         }    #T_f5f8e60a_087e_11eb_b041_9c7bef15ac82row1_col0 {
#             color:  red;
#         }    #T_f5f8e60a_087e_11eb_b041_9c7bef15ac82row2_col0 {
#             color:  red;
#         }    #T_f5f8e60a_087e_11eb_b041_9c7bef15ac82row3_col0 {
#             color:  red;
#         }    #T_f5f8e60a_087e_11eb_b041_9c7bef15ac82row4_col0 {
#             color:  green;
#         }    #T_f5f8e60a_087e_11eb_b041_9c7bef15ac82row5_col0 {
#             color:  green;
#         }</style><table id="T_f5f8e60a_087e_11eb_b041_9c7bef15ac82" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ApplicantIncome</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f5f8e60a_087e_11eb_b041_9c7bef15ac82level0_row0" class="row_heading level0 row0" >0</th>
# ...
